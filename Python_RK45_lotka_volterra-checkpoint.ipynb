# %%
from scipy import integrate
import matplotlib.pyplot as plt
import numpy as np

# %%
def rk45_lotka_volterra(func,tspan,y0,params):
    #func      the function used to describe the lotka volterra system
    #tspan     the interval of time
    #y0        initial conditions, should be an 1-d array of size (n,)
    #params      an array that should contain 4 parameters a,b,c,d
    #a           birth rate of rabbits
    #b           death rate of rabbits
    #c           bith rate of foxes
    #d           death rate of foxes
    sol=integrate.solve_ivp(func,tspan,y0,max_step=0.33,args=(params,))#I really don't understand this args=(params,)syntax, 
    #but it should be able to pass on the parameters, I don't understand why is it written in this way though, 
    #and why wouldn't it return some form of tuple.
    T=sol.t
    sol=sol.y
    rabbit=sol[0]#the values array for rabbits
    fox=sol[1]#the values array for foxes
    time=T[-1]
    num_rabbit=rabbit[-1]
    num_fox=fox[-1]
    print('at t=',time,', the number of the rabbits are',num_rabbit,', the number of the foxes are',num_fox)
    plt.plot(T,rabbit,'r')
    plt.plot(T,fox,'b')#the blue line will be the number of foxes.
    plt.xlabel('time')
    plt.title('runge kutta method')
    plt.show
    #I don't want to return anything

# %%
def lotka_volterra(t,y,params):#the function to describe the drabbits and dfoxes.
    #y           an array containing the 1) the number of rabbits 2) the number of foxes.
    #params      an array that should contain 4 parameters a,b,c,d
    #a           birth rate of rabbits
    #b           death rate of rabbits
    #c           bith rate of foxes
    #d           death rate of foxes
    a=params[0]
    b=params[1]
    c=params[2]
    d=params[3]
    X=y[0]
    Y=y[1]
    dx=(a*X)-(b*X*Y)
    dy=(c*X*Y)-(d*Y)
    return([dx,dy])

# %%
tspan=[0,500]
y0=[200,10]
params=[3.5,0.1,0.1,0.3]
rk45_lotka_volterra(lotka_volterra,tspan,y0,params)#The sharp increases points merge again, I don't knwo how to fix that
# Out:
# at t= 500.0 , the number of the rabbits are 2.8896792143828206e-06 , the number of the foxes are 82.52115361309745

# %%
tspan=[0,500]
y0=[200,10]
params=[1.5,0.05,0.1,0.3]
rk45_lotka_volterra(lotka_volterra,tspan,y0,params)#different results due to change of the parameters, it means my args argument indeed successfully
#passed on the parameters to the function
# Out:
# at t= 500.0 , the number of the rabbits are 2.721279870447643e-05 , the number of the foxes are 0.7843452324318362

# %%
tspan=[0,500]
y0=[100,10]
params=[3.5,0.35,0.003,0.3]
rk45_lotka_volterra(lotka_volterra,tspan,y0,params)#the steady state
# Out:
# at t= 500.0 , the number of the rabbits are 100.0 , the number of the foxes are 10.0
